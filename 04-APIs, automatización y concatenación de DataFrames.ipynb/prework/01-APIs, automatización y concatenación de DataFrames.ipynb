# %% [markdown]
# # PREWORK de APIs, automatización y concatenación de DataFrames
#
# ## Introducción
# En este Prework vamos a aprender a adquirir datos de una nueva fuente: las APIs.
#
# También vamos a aprovechar esto para aprender a automatizar procesos. Vamos a aprender un poquito sobre un par de estructuras que podemos usar en Python para hacer automatizaciones: for loops y excepciones.
#
# Para terminar vamos a realizar un exploración acerca de una de las maneras que tenemos de unir DataFrames: la concatenación.
#
#
# ## Objetivos
# - Hacer peticiones a APIs.
# - Automatizar peticiones a APIs utilizando For loops y Excepciones.
# - Usar concat para unir múltiples Series.
# - Indexar usando Multiíndices en filas
# - Usar concat para unir múltiples DataFrames.
# - Guardar datasets localmente en formato .csv.

# %% [markdown]
# ### APIs
#
# Una API es una interfaz para comunicarnos con un software que está corriendo en algún servidor remoto. Normalmente, una API se usa para obtener datos acerca de algún tema en específico. Diferentes compañías, instituciones, universidades, etc, tienen APIs para que nosotros (programadores/desarrolladores/científicos de datos) podamos construir programas usando los datos que ofrecen. Hay una infinidad de APIs que ofrecen una gran diversidad de información.
#
# Hoy vamos a aprender a comunicarnos con una para pedir datos y vamos a aprender a automatizar nuestras peticiones. Pero primero, un poquito de teoría.
#
# #### Peticiones HTTP
# Una peticiones HTTP es una solicitud de información de un cliente a un servidor usando el protocolo HTTP. El protocolo HTTP es simplemente una serie de reglas que nos dicen cuál es la manera apropiada de comunicarnos con el servidor.
#
# #### Endpoints y URLs
# Los URLs son las direcciones a donde pedimos información. Una API tiene normalmente una documentación donde te indica cuáles son los URLs disponibles. Cada URL apunta hacia información o recursos distintos. Usamos algún tipo de software (Postman o Request) para "llamar" dicho endpoint (URL) y aplicar una acción.
#
# #### Verbos HTTP
# Cuando realizamos una petición HTTP usamos 1 tipo de "verbo", que indica la acción que queremos realizar. Hay muchos verbos, pero 5 son los más importantes:
#
# 1. GET: Lo usamos cuando queremos pedir información
# 2. POST: Lo usamos cuando queremos enviar información para crear algo (una cuenta de usuario, por ejemplo)
# 3. PUT: Lo usamos cuando queremos sustituir algún dato por otro
# 4. PATCH: Lo usamos cuando queremos modificar algún dato
# 5. DELETE: Lo usamos cuando queremos eliminar algún dato
#
# Para los propósitos de la adquisición de datos, el verbo que más nos interesa es el verbo GET (si quieres saber más sobre los demás verbos, puedes ir aquí), así que usaremos solamente ése.
#
# #### Parámetros
#
# Cuando hacemos una solicitud HTTP, normalmente vamos a tener que enviar parámetros para delimitar nuestras búsquedas. Los parámetros funcionan de manera similar a los parámetros de las funciones, tienen un nombre y le pasamos un valor como argumento. Los parámetros que enviemos determinarán qué datos vamos a obtener de regreso y en qué forma.
#
# #### Respuestas
# Las respuestas son los datos que recibimos de una API. Normalmente los datos que se transifieren a través de una API están en formato JSON. Las respuestas contienen los datos que solicitamos, algo "metadata" (datos acerca de los datos) y un estatus de la petición.
#
# #### Estatus de la petición
# Cuando recibimos una respuesta, vamos también a recibir un código de estatus que sirve para identificar cuál fue el resultado de nuestra solicitud. También hay muchísimos estatus distintos, pero los más importantes son los siguientes:
#
# 1. 200: Todo salió bien.
# 1. 201: Los recursos que querías crear fueron creados con éxito
# 1. 404: El recurso no fue encontrado en ese URL
# 1. 400: Los datos que enviaste son incorrectos
# 1. 500: Hubo un error interno en el servidor
#
# #### Librería Requests
#
# ¡Estamos listos para hacer nuestras peticiones HTTP! Antes que nada, hay que instalar la librería de Python que usaremos para hacer nuestras peticiones: requests. Google Colab no incluye esta librería y por lo tanto es necesario instalarla manualmente
#
# En una celda de tu JN escribe el comando !pip install requests y corre la celda para instalar la librería. Ahora se ha instalado esta librería en esta celda. Cada vez que quieras usar esta librería en un JN distinto tendrás que volver a realizar la instalación, puesto que todo se resetea.

# %% [markdown]
# Entonces, vamos a importar requests en un Jupyter Notebooks:

# %%
import requests

# %% [markdown]
# Vamos a obtener datos de fotos

# %%
url = 'https://api.nasa.gov/neo/rest/v1/feed'
api_key={'api_key':'2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'}

# %% [markdown]
# Vamos a realizar una petición GET usando requests a ver qué pasa:

# %%
response = requests.get(url, params=api_key)

# %% [markdown]
# Ok... ¿Y ahora qué?
#
# Un primer paso sería revisar el estatus de la llamada:

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# Podemos ver un poco más de información pidiendo el cuerpo de la respuest en formato json:

# %%
data = response.json()
data
# Out:
# {'links': {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-06-23&end_date=2024-06-30&detailed=false&api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d',
#   'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-06-09&end_date=2024-06-16&detailed=false&api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d',
#   'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-06-16&end_date=2024-06-23&detailed=false&api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#  'element_count': 102,
#  'near_earth_objects': {'2024-06-19': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2137158?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '2137158',
#     'neo_reference_id': '2137158',
#     'name': '137158 (1999 FB)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2137158',
#     'absolute_magnitude_h': 17.92,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.6927156136,
#       'estimated_diameter_max': 1.5489592011},
#      'meters': {'estimated_diameter_min': 692.7156135897,
#       'estimated_diameter_max': 1548.9592010621},
#      'miles': {'estimated_diameter_min': 0.4304333935,
#       'estimated_diameter_max': 0.9624783277},
#      'feet': {'estimated_diameter_min': 2272.6890936897,
#       'estimated_diameter_max': 5081.8873052124}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 04:35',
#       'epoch_date_close_approach': 1718771700000,
#       'relative_velocity': {'kilometers_per_second': '30.0834647163',
#        'kilometers_per_hour': '108300.4729788197',
#        'miles_per_hour': '67293.7022239783'},
#       'miss_distance': {'astronomical': '0.4128674724',
#        'lunar': '160.6054467636',
#        'kilometers': '61764094.463323788',
#        'miles': '38378428.6681247544'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3398650?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '3398650',
#     'neo_reference_id': '3398650',
#     'name': '(2007 YO56)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3398650',
#     'absolute_magnitude_h': 20.15,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2480589932,
#       'estimated_diameter_max': 0.5546767711},
#      'meters': {'estimated_diameter_min': 248.0589931518,
#       'estimated_diameter_max': 554.6767711177},
#      'miles': {'estimated_diameter_min': 0.1541366646,
#       'estimated_diameter_max': 0.3446600599},
#      'feet': {'estimated_diameter_min': 813.8418670923,
#       'estimated_diameter_max': 1819.8057377537}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 13:04',
#       'epoch_date_close_approach': 1718802240000,
#       'relative_velocity': {'kilometers_per_second': '12.3227458622',
#        'kilometers_per_hour': '44361.8851039531',
#        'miles_per_hour': '27564.7502191758'},
#       'miss_distance': {'astronomical': '0.2125126605',
#        'lunar': '82.6674249345',
#        'kilometers': '31791441.358833135',
#        'miles': '19754285.641981863'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3634786?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '3634786',
#     'neo_reference_id': '3634786',
#     'name': '(2013 GX79)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3634786',
#     'absolute_magnitude_h': 20.78,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.185590173,
#       'estimated_diameter_max': 0.4149922428},
#      'meters': {'estimated_diameter_min': 185.5901730037,
#       'estimated_diameter_max': 414.9922427922},
#      'miles': {'estimated_diameter_min': 0.1153203514,
#       'estimated_diameter_max': 0.2578641449},
#      'feet': {'estimated_diameter_min': 608.8916631975,
#       'estimated_diameter_max': 1361.5231498425}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 14:47',
#       'epoch_date_close_approach': 1718808420000,
#       'relative_velocity': {'kilometers_per_second': '10.6257619846',
#        'kilometers_per_hour': '38252.7431445517',
#        'miles_per_hour': '23768.7669833466'},
#       'miss_distance': {'astronomical': '0.4609156399',
#        'lunar': '179.2961839211',
#        'kilometers': '68951997.978727013',
#        'miles': '42844784.8049102594'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3645310?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '3645310',
#     'neo_reference_id': '3645310',
#     'name': '(2013 PF10)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3645310',
#     'absolute_magnitude_h': 20.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2424124811,
#       'estimated_diameter_max': 0.5420507863},
#      'meters': {'estimated_diameter_min': 242.4124811008,
#       'estimated_diameter_max': 542.0507863358},
#      'miles': {'estimated_diameter_min': 0.1506280858,
#       'estimated_diameter_max': 0.3368146392},
#      'feet': {'estimated_diameter_min': 795.3165644948,
#       'estimated_diameter_max': 1778.3819018419}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 22:40',
#       'epoch_date_close_approach': 1718836800000,
#       'relative_velocity': {'kilometers_per_second': '21.4280214347',
#        'kilometers_per_hour': '77140.8771649823',
#        'miles_per_hour': '47932.3411473191'},
#       'miss_distance': {'astronomical': '0.3717256163',
#        'lunar': '144.6012647407',
#        'kilometers': '55609360.422917281',
#        'miles': '34554054.2740132378'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3683806?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '3683806',
#     'neo_reference_id': '3683806',
#     'name': '(2014 QO296)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3683806',
#     'absolute_magnitude_h': 20.14,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2492039814,
#       'estimated_diameter_max': 0.5572370428},
#      'meters': {'estimated_diameter_min': 249.2039814409,
#       'estimated_diameter_max': 557.2370427654},
#      'miles': {'estimated_diameter_min': 0.1548481272,
#       'estimated_diameter_max': 0.3462509385},
#      'feet': {'estimated_diameter_min': 817.5983904706,
#       'estimated_diameter_max': 1828.2055793866}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 20:47',
#       'epoch_date_close_approach': 1718830020000,
#       'relative_velocity': {'kilometers_per_second': '12.6133465735',
#        'kilometers_per_hour': '45408.0476645348',
#        'miles_per_hour': '28214.7949502217'},
#       'miss_distance': {'astronomical': '0.2411761995',
#        'lunar': '93.8175416055',
#        'kilometers': '36079445.739895065',
#        'miles': '22418728.012539297'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3727339?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '3727339',
#     'neo_reference_id': '3727339',
#     'name': '(2015 RK82)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3727339',
#     'absolute_magnitude_h': 20.64,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1979497587,
#       'estimated_diameter_max': 0.4426291165},
#      'meters': {'estimated_diameter_min': 197.9497586642,
#       'estimated_diameter_max': 442.6291165029},
#      'miles': {'estimated_diameter_min': 0.1230002395,
#       'estimated_diameter_max': 0.2750368968},
#      'feet': {'estimated_diameter_min': 649.4414862159,
#       'estimated_diameter_max': 1452.1953105872}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 07:35',
#       'epoch_date_close_approach': 1718782500000,
#       'relative_velocity': {'kilometers_per_second': '6.7154890488',
#        'kilometers_per_hour': '24175.7605755197',
#        'miles_per_hour': '15021.8774531611'},
#       'miss_distance': {'astronomical': '0.3041248386',
#        'lunar': '118.3045622154',
#        'kilometers': '45496428.068653782',
#        'miles': '28270169.4966829116'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3760437?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '3760437',
#     'neo_reference_id': '3760437',
#     'name': '(2016 TH10)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3760437',
#     'absolute_magnitude_h': 24.81,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0290104841,
#       'estimated_diameter_max': 0.0648694146},
#      'meters': {'estimated_diameter_min': 29.0104841428,
#       'estimated_diameter_max': 64.8694146035},
#      'miles': {'estimated_diameter_min': 0.0180262735,
#       'estimated_diameter_max': 0.040307973},
#      'feet': {'estimated_diameter_min': 95.1787567951,
#       'estimated_diameter_max': 212.8261702077}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 22:55',
#       'epoch_date_close_approach': 1718837700000,
#       'relative_velocity': {'kilometers_per_second': '6.536129921',
#        'kilometers_per_hour': '23530.0677156535',
#        'miles_per_hour': '14620.6690203182'},
#       'miss_distance': {'astronomical': '0.4394605853',
#        'lunar': '170.9501676817',
#        'kilometers': '65742367.509833311',
#        'miles': '40850412.9117932518'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3843119?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '3843119',
#     'neo_reference_id': '3843119',
#     'name': '(2019 NP1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3843119',
#     'absolute_magnitude_h': 25.09,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0255008688,
#       'estimated_diameter_max': 0.0570216761},
#      'meters': {'estimated_diameter_min': 25.5008687857,
#       'estimated_diameter_max': 57.0216760901},
#      'miles': {'estimated_diameter_min': 0.0158455003,
#       'estimated_diameter_max': 0.0354316159},
#      'feet': {'estimated_diameter_min': 83.6642703469,
#       'estimated_diameter_max': 187.0789957835}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 00:47',
#       'epoch_date_close_approach': 1718758020000,
#       'relative_velocity': {'kilometers_per_second': '19.462811725',
#        'kilometers_per_hour': '70066.1222101271',
#        'miles_per_hour': '43536.3635477315'},
#       'miss_distance': {'astronomical': '0.2667530283',
#        'lunar': '103.7669280087',
#        'kilometers': '39905684.849729721',
#        'miles': '24796242.7485673098'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54099636?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54099636',
#     'neo_reference_id': '54099636',
#     'name': '(2020 XV3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54099636',
#     'absolute_magnitude_h': 22.84,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0718712133,
#       'estimated_diameter_max': 0.1607089186},
#      'meters': {'estimated_diameter_min': 71.871213318,
#       'estimated_diameter_max': 160.7089186045},
#      'miles': {'estimated_diameter_min': 0.0446586877,
#       'estimated_diameter_max': 0.0998598615},
#      'feet': {'estimated_diameter_min': 235.7979515023,
#       'estimated_diameter_max': 527.2602485143}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 20:40',
#       'epoch_date_close_approach': 1718829600000,
#       'relative_velocity': {'kilometers_per_second': '18.9466007183',
#        'kilometers_per_hour': '68207.7625858048',
#        'miles_per_hour': '42381.6511467185'},
#       'miss_distance': {'astronomical': '0.2295710248',
#        'lunar': '89.3031286472',
#        'kilometers': '34343336.323797176',
#        'miles': '21339959.6445299888'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54159401?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54159401',
#     'neo_reference_id': '54159401',
#     'name': '(2021 LD6)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54159401',
#     'absolute_magnitude_h': 27.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0096506147,
#       'estimated_diameter_max': 0.0215794305},
#      'meters': {'estimated_diameter_min': 9.6506146958,
#       'estimated_diameter_max': 21.5794304844},
#      'miles': {'estimated_diameter_min': 0.0059966121,
#       'estimated_diameter_max': 0.0134088323},
#      'feet': {'estimated_diameter_min': 31.6621227185,
#       'estimated_diameter_max': 70.7986587106}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 09:09',
#       'epoch_date_close_approach': 1718788140000,
#       'relative_velocity': {'kilometers_per_second': '10.6741595593',
#        'kilometers_per_hour': '38426.9744135412',
#        'miles_per_hour': '23877.0275182362'},
#       'miss_distance': {'astronomical': '0.2650879971',
#        'lunar': '103.1192308719',
#        'kilometers': '39656599.728726177',
#        'miles': '24641468.4313561626'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': True,
#     'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54159401?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54169408?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54169408',
#     'neo_reference_id': '54169408',
#     'name': '(2021 NT5)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54169408',
#     'absolute_magnitude_h': 27.12,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.010012787,
#       'estimated_diameter_max': 0.0223892723},
#      'meters': {'estimated_diameter_min': 10.012786977,
#       'estimated_diameter_max': 22.3892723248},
#      'miles': {'estimated_diameter_min': 0.0062216555,
#       'estimated_diameter_max': 0.0139120445},
#      'feet': {'estimated_diameter_min': 32.8503520256,
#       'estimated_diameter_max': 73.455620214}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 20:13',
#       'epoch_date_close_approach': 1718827980000,
#       'relative_velocity': {'kilometers_per_second': '16.5746624937',
#        'kilometers_per_hour': '59668.7849772487',
#        'miles_per_hour': '37075.8625321132'},
#       'miss_distance': {'astronomical': '0.3496937767',
#        'lunar': '136.0308791363',
#        'kilometers': '52313444.146575629',
#        'miles': '32506066.8663325202'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2577723?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '2577723',
#     'neo_reference_id': '2577723',
#     'name': '577723 (2013 PF10)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2577723',
#     'absolute_magnitude_h': 20.17,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2457847746,
#       'estimated_diameter_max': 0.5495914639},
#      'meters': {'estimated_diameter_min': 245.7847746328,
#       'estimated_diameter_max': 549.5914639134},
#      'miles': {'estimated_diameter_min': 0.1527235312,
#       'estimated_diameter_max': 0.3415001975},
#      'feet': {'estimated_diameter_min': 806.3805200062,
#       'estimated_diameter_max': 1803.1216584655}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 22:40',
#       'epoch_date_close_approach': 1718836800000,
#       'relative_velocity': {'kilometers_per_second': '21.4280239324',
#        'kilometers_per_hour': '77140.8861567635',
#        'miles_per_hour': '47932.3467344623'},
#       'miss_distance': {'astronomical': '0.3717256532',
#        'lunar': '144.6012790948',
#        'kilometers': '55609365.943078684',
#        'miles': '34554057.7040824792'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54276148?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54276148',
#     'neo_reference_id': '54276148',
#     'name': '(2022 HK)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54276148',
#     'absolute_magnitude_h': 23.15,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0623096019,
#       'estimated_diameter_max': 0.1393285055},
#      'meters': {'estimated_diameter_min': 62.3096019112,
#       'estimated_diameter_max': 139.3285055244},
#      'miles': {'estimated_diameter_min': 0.0387173796,
#       'estimated_diameter_max': 0.0865746928},
#      'feet': {'estimated_diameter_min': 204.4278343344,
#       'estimated_diameter_max': 457.1145340647}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 07:59',
#       'epoch_date_close_approach': 1718783940000,
#       'relative_velocity': {'kilometers_per_second': '30.8767723778',
#        'kilometers_per_hour': '111156.3805600184',
#        'miles_per_hour': '69068.2521318626'},
#       'miss_distance': {'astronomical': '0.3621392397',
#        'lunar': '140.8721642433',
#        'kilometers': '54175258.902539439',
#        'miles': '33662944.9105406982'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54402372?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54402372',
#     'neo_reference_id': '54402372',
#     'name': '(2023 VW)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54402372',
#     'absolute_magnitude_h': 27.99,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0067074119,
#       'estimated_diameter_max': 0.0149982289},
#      'meters': {'estimated_diameter_min': 6.7074118933,
#       'estimated_diameter_max': 14.9982289464},
#      'miles': {'estimated_diameter_min': 0.0041677912,
#       'estimated_diameter_max': 0.0093194645},
#      'feet': {'estimated_diameter_min': 22.0059452359,
#       'estimated_diameter_max': 49.2067894565}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 23:43',
#       'epoch_date_close_approach': 1718840580000,
#       'relative_velocity': {'kilometers_per_second': '7.6424297579',
#        'kilometers_per_hour': '27512.7471285642',
#        'miles_per_hour': '17095.3511255237'},
#       'miss_distance': {'astronomical': '0.4045022747',
#        'lunar': '157.3513848583',
#        'kilometers': '60512678.705274889',
#        'miles': '37600834.9735719082'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54414149?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54414149',
#     'neo_reference_id': '54414149',
#     'name': '(2023 XD3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54414149',
#     'absolute_magnitude_h': 27.04,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.010388551,
#       'estimated_diameter_max': 0.0232295062},
#      'meters': {'estimated_diameter_min': 10.3885510102,
#       'estimated_diameter_max': 23.2295062464},
#      'miles': {'estimated_diameter_min': 0.0064551443,
#       'estimated_diameter_max': 0.0144341415},
#      'feet': {'estimated_diameter_min': 34.0831736962,
#       'estimated_diameter_max': 76.2122932736}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 06:29',
#       'epoch_date_close_approach': 1718778540000,
#       'relative_velocity': {'kilometers_per_second': '4.8873026228',
#        'kilometers_per_hour': '17594.2894421796',
#        'miles_per_hour': '10932.4072370032'},
#       'miss_distance': {'astronomical': '0.2545145088',
#        'lunar': '99.0061439232',
#        'kilometers': '38074828.400576256',
#        'miles': '23658601.3041980928'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2663927?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '2663927',
#     'neo_reference_id': '2663927',
#     'name': '663927 (2007 YO56)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2663927',
#     'absolute_magnitude_h': 20.15,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2480589932,
#       'estimated_diameter_max': 0.5546767711},
#      'meters': {'estimated_diameter_min': 248.0589931518,
#       'estimated_diameter_max': 554.6767711177},
#      'miles': {'estimated_diameter_min': 0.1541366646,
#       'estimated_diameter_max': 0.3446600599},
#      'feet': {'estimated_diameter_min': 813.8418670923,
#       'estimated_diameter_max': 1819.8057377537}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 13:04',
#       'epoch_date_close_approach': 1718802240000,
#       'relative_velocity': {'kilometers_per_second': '12.3227458509',
#        'kilometers_per_hour': '44361.8850631828',
#        'miles_per_hour': '27564.7501938426'},
#       'miss_distance': {'astronomical': '0.2125126604',
#        'lunar': '82.6674248956',
#        'kilometers': '31791441.343873348',
#        'miles': '19754285.6326862824'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2671970?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '2671970',
#     'neo_reference_id': '2671970',
#     'name': '671970 (2014 QO296)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2671970',
#     'absolute_magnitude_h': 20.15,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2480589932,
#       'estimated_diameter_max': 0.5546767711},
#      'meters': {'estimated_diameter_min': 248.0589931518,
#       'estimated_diameter_max': 554.6767711177},
#      'miles': {'estimated_diameter_min': 0.1541366646,
#       'estimated_diameter_max': 0.3446600599},
#      'feet': {'estimated_diameter_min': 813.8418670923,
#       'estimated_diameter_max': 1819.8057377537}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 20:47',
#       'epoch_date_close_approach': 1718830020000,
#       'relative_velocity': {'kilometers_per_second': '12.613343853',
#        'kilometers_per_hour': '45408.0378708184',
#        'miles_per_hour': '28214.7888647871'},
#       'miss_distance': {'astronomical': '0.2411762945',
#        'lunar': '93.8175785605',
#        'kilometers': '36079459.951692715',
#        'miles': '22418736.843340867'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54445450?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54445450',
#     'neo_reference_id': '54445450',
#     'name': '(2024 KY1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54445450',
#     'absolute_magnitude_h': 24.98,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0268259417,
#       'estimated_diameter_max': 0.0599846292},
#      'meters': {'estimated_diameter_min': 26.8259417119,
#       'estimated_diameter_max': 59.9846292283},
#      'miles': {'estimated_diameter_min': 0.0166688622,
#       'estimated_diameter_max': 0.037272709},
#      'feet': {'estimated_diameter_min': 88.0116226061,
#       'estimated_diameter_max': 196.7999709574}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-19',
#       'close_approach_date_full': '2024-Jun-19 17:32',
#       'epoch_date_close_approach': 1718818320000,
#       'relative_velocity': {'kilometers_per_second': '12.2245715197',
#        'kilometers_per_hour': '44008.4574709394',
#        'miles_per_hour': '27345.144032429'},
#       'miss_distance': {'astronomical': '0.0412075576',
#        'lunar': '16.0297399064',
#        'kilometers': '6164562.844862312',
#        'miles': '3830481.7299994256'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-06-18': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2458452?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '2458452',
#     'neo_reference_id': '2458452',
#     'name': '458452 (2011 BR15)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2458452',
#     'absolute_magnitude_h': 19.77,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2954982931,
#       'estimated_diameter_max': 0.6607542706},
#      'meters': {'estimated_diameter_min': 295.4982931114,
#       'estimated_diameter_max': 660.7542706324},
#      'miles': {'estimated_diameter_min': 0.1836140699,
#       'estimated_diameter_max': 0.4105735419},
#      'feet': {'estimated_diameter_min': 969.4826199718,
#       'estimated_diameter_max': 2167.8290412615}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-18',
#       'close_approach_date_full': '2024-Jun-18 07:57',
#       'epoch_date_close_approach': 1718697420000,
#       'relative_velocity': {'kilometers_per_second': '12.9000277818',
#        'kilometers_per_hour': '46440.1000146154',
#        'miles_per_hour': '28856.0721451925'},
#       'miss_distance': {'astronomical': '0.3910440929',
#        'lunar': '152.1161521381',
#        'kilometers': '58499363.373922123',
#        'miles': '36349818.8370583774'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3330686?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '3330686',
#     'neo_reference_id': '3330686',
#     'name': '(2006 HX30)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3330686',
#     'absolute_magnitude_h': 26.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0152951935,
#       'estimated_diameter_max': 0.0342010925},
#      'meters': {'estimated_diameter_min': 15.2951935344,
#       'estimated_diameter_max': 34.201092472},
#      'miles': {'estimated_diameter_min': 0.0095039897,
#       'estimated_diameter_max': 0.021251567},
#      'feet': {'estimated_diameter_min': 50.1810827555,
#       'estimated_diameter_max': 112.2083122258}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-18',
#       'close_approach_date_full': '2024-Jun-18 19:26',
#       'epoch_date_close_approach': 1718738760000,
#       'relative_velocity': {'kilometers_per_second': '12.1815283838',
#        'kilometers_per_hour': '43853.5021817203',
#        'miles_per_hour': '27248.8608417473'},
#       'miss_distance': {'astronomical': '0.2596113273',
#        'lunar': '100.9888063197',
#        'kilometers': '38837301.591952851',
#        'miles': '24132380.1759013038'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3761354?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '3761354',
#     'neo_reference_id': '3761354',
#     'name': '(2016 UR5)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3761354',
#     'absolute_magnitude_h': 26.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0121494041,
#       'estimated_diameter_max': 0.0271668934},
#      'meters': {'estimated_diameter_min': 12.14940408,
#       'estimated_diameter_max': 27.1668934089},
#      'miles': {'estimated_diameter_min': 0.0075492874,
#       'estimated_diameter_max': 0.0168807197},
#      'feet': {'estimated_diameter_min': 39.8602508817,
#       'estimated_diameter_max': 89.1302305717}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-18',
#       'close_approach_date_full': '2024-Jun-18 22:01',
#       'epoch_date_close_approach': 1718748060000,
#       'relative_velocity': {'kilometers_per_second': '9.8990991229',
#        'kilometers_per_hour': '35636.7568424304',
#        'miles_per_hour': '22143.294828009'},
#       'miss_distance': {'astronomical': '0.2548439238',
#        'lunar': '99.1342863582',
#        'kilometers': '38124108.182922306',
#        'miles': '23689222.3410315828'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54102026?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54102026',
#     'neo_reference_id': '54102026',
#     'name': '(2020 YW3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54102026',
#     'absolute_magnitude_h': 25.73,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0189913123,
#       'estimated_diameter_max': 0.0424658654},
#      'meters': {'estimated_diameter_min': 18.9913123471,
#       'estimated_diameter_max': 42.46586539},
#      'miles': {'estimated_diameter_min': 0.0118006507,
#       'estimated_diameter_max': 0.0263870572},
#      'feet': {'estimated_diameter_min': 62.3074572008,
#       'estimated_diameter_max': 139.3237098062}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-18',
#       'close_approach_date_full': '2024-Jun-18 07:54',
#       'epoch_date_close_approach': 1718697240000,
#       'relative_velocity': {'kilometers_per_second': '11.5012452234',
#        'kilometers_per_hour': '41404.4828040913',
#        'miles_per_hour': '25727.1354401311'},
#       'miss_distance': {'astronomical': '0.3547421506',
#        'lunar': '137.9946965834',
#        'kilometers': '53068670.128979222',
#        'miles': '32975342.5311963836'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54159398?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54159398',
#     'neo_reference_id': '54159398',
#     'name': '(2021 LA6)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54159398',
#     'absolute_magnitude_h': 25.73,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0189913123,
#       'estimated_diameter_max': 0.0424658654},
#      'meters': {'estimated_diameter_min': 18.9913123471,
#       'estimated_diameter_max': 42.46586539},
#      'miles': {'estimated_diameter_min': 0.0118006507,
#       'estimated_diameter_max': 0.0263870572},
#      'feet': {'estimated_diameter_min': 62.3074572008,
#       'estimated_diameter_max': 139.3237098062}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-18',
#       'close_approach_date_full': '2024-Jun-18 10:55',
#       'epoch_date_close_approach': 1718708100000,
#       'relative_velocity': {'kilometers_per_second': '11.7269311702',
#        'kilometers_per_hour': '42216.9522128618',
#        'miles_per_hour': '26231.9723347085'},
#       'miss_distance': {'astronomical': '0.1610060842',
#        'lunar': '62.6313667538',
#        'kilometers': '24086167.253360654',
#        'miles': '14966450.3277148652'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54224163?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54224163',
#     'neo_reference_id': '54224163',
#     'name': '(2021 WH1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54224163',
#     'absolute_magnitude_h': 21.44,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1369477737,
#       'estimated_diameter_max': 0.3062245314},
#      'meters': {'estimated_diameter_min': 136.9477737298,
#       'estimated_diameter_max': 306.2245314272},
#      'miles': {'estimated_diameter_min': 0.0850953751,
#       'estimated_diameter_max': 0.1902790433},
#      'feet': {'estimated_diameter_min': 449.3037339638,
#       'estimated_diameter_max': 1004.6736916875}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-18',
#       'close_approach_date_full': '2024-Jun-18 01:16',
#       'epoch_date_close_approach': 1718673360000,
#       'relative_velocity': {'kilometers_per_second': '13.6070737849',
#        'kilometers_per_hour': '48985.4656256274',
#        'miles_per_hour': '30437.663349435'},
#       'miss_distance': {'astronomical': '0.3912876472',
#        'lunar': '152.2108947608',
#        'kilometers': '58535798.578431464',
#        'miles': '36372458.6233196432'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54296729?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54296729',
#     'neo_reference_id': '54296729',
#     'name': '(2022 QC2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54296729',
#     'absolute_magnitude_h': 25.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0201629919,
#       'estimated_diameter_max': 0.0450858206},
#      'meters': {'estimated_diameter_min': 20.1629919443,
#       'estimated_diameter_max': 45.0858206172},
#      'miles': {'estimated_diameter_min': 0.0125286985,
#       'estimated_diameter_max': 0.0280150214},
#      'feet': {'estimated_diameter_min': 66.1515504905,
#       'estimated_diameter_max': 147.9193637137}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-18',
#       'close_approach_date_full': '2024-Jun-18 17:41',
#       'epoch_date_close_approach': 1718732460000,
#       'relative_velocity': {'kilometers_per_second': '15.3989313351',
#        'kilometers_per_hour': '55436.1528064784',
#        'miles_per_hour': '34445.8695035588'},
#       'miss_distance': {'astronomical': '0.4360921802',
#        'lunar': '169.6398580978',
#        'kilometers': '65238461.281576174',
#        'miles': '40537300.1007882412'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54441688?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54441688',
#     'neo_reference_id': '54441688',
#     'name': '(2024 JZ14)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54441688',
#     'absolute_magnitude_h': 24.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0421264611,
#       'estimated_diameter_max': 0.0941976306},
#      'meters': {'estimated_diameter_min': 42.1264610556,
#       'estimated_diameter_max': 94.1976305719},
#      'miles': {'estimated_diameter_min': 0.0261761612,
#       'estimated_diameter_max': 0.0585316759},
#      'feet': {'estimated_diameter_min': 138.2101784897,
#       'estimated_diameter_max': 309.0473542854}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-18',
#       'close_approach_date_full': '2024-Jun-18 15:59',
#       'epoch_date_close_approach': 1718726340000,
#       'relative_velocity': {'kilometers_per_second': '6.0282183247',
#        'kilometers_per_hour': '21701.585968999',
#        'miles_per_hour': '13484.5215705705'},
#       'miss_distance': {'astronomical': '0.1271454077',
#        'lunar': '49.4595635953',
#        'kilometers': '19020682.172201599',
#        'miles': '11818903.8519521062'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54445205?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54445205',
#     'neo_reference_id': '54445205',
#     'name': '(2024 KG1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54445205',
#     'absolute_magnitude_h': 23.23,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0600558028,
#       'estimated_diameter_max': 0.1342888574},
#      'meters': {'estimated_diameter_min': 60.0558027725,
#       'estimated_diameter_max': 134.2888574426},
#      'miles': {'estimated_diameter_min': 0.0373169342,
#       'estimated_diameter_max': 0.0834432016},
#      'feet': {'estimated_diameter_min': 197.033479968,
#       'estimated_diameter_max': 440.5802550519}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-18',
#       'close_approach_date_full': '2024-Jun-18 23:05',
#       'epoch_date_close_approach': 1718751900000,
#       'relative_velocity': {'kilometers_per_second': '6.1383679911',
#        'kilometers_per_hour': '22098.1247678556',
#        'miles_per_hour': '13730.9153592267'},
#       'miss_distance': {'astronomical': '0.1914229188',
#        'lunar': '74.4635154132',
#        'kilometers': '28636460.921662956',
#        'miles': '17793871.7039265528'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-06-17': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3555763?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '3555763',
#     'neo_reference_id': '3555763',
#     'name': '(2011 BY18)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3555763',
#     'absolute_magnitude_h': 20.83,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1813656249,
#       'estimated_diameter_max': 0.4055458661},
#      'meters': {'estimated_diameter_min': 181.3656249029,
#       'estimated_diameter_max': 405.5458660645},
#      'miles': {'estimated_diameter_min': 0.1126953397,
#       'estimated_diameter_max': 0.2519944403},
#      'feet': {'estimated_diameter_min': 595.0315968063,
#       'estimated_diameter_max': 1330.5310992191}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-06-17',
#       'close_approach_date_full': '2024-Jun-17 13:56',
#       'epoch_date_close_approach': 1718632560000,
#       'relative_velocity': {'kilometers_per_second': '29.9587782334',
#        'kilometers_per_hour': '107851.6016403808',
#        'miles_per_hour': '67014.7910303799'},
#       'miss_distance': {'astronomical': '0.1825771012',
#        'lunar': '71.0224923668',
#        'kilometers': '27313145.450294444',
#        'miles': '16971601.5991895672'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3582523?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '3582523',
#     'neo_reference_id': '3582523',
#     'name': '(2011 UC64)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3582523',
#     'absolute_magnitude_h': 27.9,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0069912523,
#       'estimated_diameter_max': 0.0156329154},
#      'meters': {'estimated_diameter_min': 6.9912523225,
#       'estimated_diameter_max': 15.6329154409},
#      'miles': {'estimated_diameter_min': 0.0043441614,
#       'estimated_diameter_max': 0.0097138403},
#      'feet': {'estimated_diameter_min': 22.9371802696,
#       'estimated_diameter_max': 51.289094295}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-17',
#       'close_approach_date_full': '2024-Jun-17 13:55',
#       'epoch_date_close_approach': 1718632500000,
#       'relative_velocity': {'kilometers_per_second': '8.8134338814',
#        'kilometers_per_hour': '31728.3619731287',
#        'miles_per_hour': '19714.7702493588'},
#       'miss_distance': {'astronomical': '0.3422400937',
#        'lunar': '133.1313964493',
#        'kilometers': '51198389.046120419',
#        'miles': '31813203.7553990222'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': True,
#     'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/3582523?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3838893?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '3838893',
#     'neo_reference_id': '3838893',
#     'name': '(2019 ES)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3838893',
#     'absolute_magnitude_h': 25.41,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0220067027,
#       'estimated_diameter_max': 0.0492084832},
#      'meters': {'estimated_diameter_min': 22.0067027115,
#       'estimated_diameter_max': 49.2084832235},
#      'miles': {'estimated_diameter_min': 0.0136743269,
#       'estimated_diameter_max': 0.0305767244},
#      'feet': {'estimated_diameter_min': 72.2004705239,
#       'estimated_diameter_max': 161.4451600989}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-17',
#       'close_approach_date_full': '2024-Jun-17 09:59',
#       'epoch_date_close_approach': 1718618340000,
#       'relative_velocity': {'kilometers_per_second': '10.0611106387',
#        'kilometers_per_hour': '36219.9982993297',
#        'miles_per_hour': '22505.6983877141'},
#       'miss_distance': {'astronomical': '0.1178357381',
#        'lunar': '45.8381021209',
#        'kilometers': '17627975.429637847',
#        'miles': '10953516.0106904086'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54051167?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54051167',
#     'neo_reference_id': '54051167',
#     'name': '(2020 PK6)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54051167',
#     'absolute_magnitude_h': 23.56,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0515887466,
#       'estimated_diameter_max': 0.1153559443},
#      'meters': {'estimated_diameter_min': 51.5887466264,
#       'estimated_diameter_max': 115.3559443307},
#      'miles': {'estimated_diameter_min': 0.0320557511,
#       'estimated_diameter_max': 0.0716788385},
#      'feet': {'estimated_diameter_min': 169.2544234818,
#       'estimated_diameter_max': 378.4643963979}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-17',
#       'close_approach_date_full': '2024-Jun-17 09:20',
#       'epoch_date_close_approach': 1718616000000,
#       'relative_velocity': {'kilometers_per_second': '11.9234443247',
#        'kilometers_per_hour': '42924.3995688545',
#        'miles_per_hour': '26671.5526098807'},
#       'miss_distance': {'astronomical': '0.1791024612',
#        'lunar': '69.6708574068',
#        'kilometers': '26793346.707277644',
#        'miles': '16648613.6374297272'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54280044?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54280044',
#     'neo_reference_id': '54280044',
#     'name': '(2022 KE2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54280044',
#     'absolute_magnitude_h': 21.69,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1220548318,
#       'estimated_diameter_max': 0.2729229009},
#      'meters': {'estimated_diameter_min': 122.054831812,
#       'estimated_diameter_max': 272.922900914},
#      'miles': {'estimated_diameter_min': 0.0758413329,
#       'estimated_diameter_max': 0.1695863759},
#      'feet': {'estimated_diameter_min': 400.4423744022,
#       'estimated_diameter_max': 895.4163702348}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-17',
#       'close_approach_date_full': '2024-Jun-17 18:21',
#       'epoch_date_close_approach': 1718648460000,
#       'relative_velocity': {'kilometers_per_second': '19.1112077993',
#        'kilometers_per_hour': '68800.3480774526',
#        'miles_per_hour': '42749.8607262372'},
#       'miss_distance': {'astronomical': '0.1630181859',
#        'lunar': '63.4140743151',
#        'kilometers': '24387173.381904033',
#        'miles': '15153486.8629923354'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54331175?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54331175',
#     'neo_reference_id': '54331175',
#     'name': '(2022 WW11)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54331175',
#     'absolute_magnitude_h': 26.87,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0112345318,
#       'estimated_diameter_max': 0.0251211767},
#      'meters': {'estimated_diameter_min': 11.2345317672,
#       'estimated_diameter_max': 25.1211767268},
#      'miles': {'estimated_diameter_min': 0.0069808122,
#       'estimated_diameter_max': 0.0156095707},
#      'feet': {'estimated_diameter_min': 36.858701203,
#       'estimated_diameter_max': 82.4185614523}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-17',
#       'close_approach_date_full': '2024-Jun-17 11:34',
#       'epoch_date_close_approach': 1718624040000,
#       'relative_velocity': {'kilometers_per_second': '14.3621067158',
#        'kilometers_per_hour': '51703.5841769822',
#        'miles_per_hour': '32126.5965126365'},
#       'miss_distance': {'astronomical': '0.0503525659',
#        'lunar': '19.5871481351',
#        'kilometers': '7532636.607674633',
#        'miles': '4680563.3474026154'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': True,
#     'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54331175?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54349260?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54349260',
#     'neo_reference_id': '54349260',
#     'name': '(2023 FG)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54349260',
#     'absolute_magnitude_h': 27.49,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0084441313,
#       'estimated_diameter_max': 0.0188816516},
#      'meters': {'estimated_diameter_min': 8.4441312798,
#       'estimated_diameter_max': 18.8816515525},
#      'miles': {'estimated_diameter_min': 0.0052469383,
#       'estimated_diameter_max': 0.0117325107},
#      'feet': {'estimated_diameter_min': 27.703843668,
#       'estimated_diameter_max': 61.9476776796}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-17',
#       'close_approach_date_full': '2024-Jun-17 05:25',
#       'epoch_date_close_approach': 1718601900000,
#       'relative_velocity': {'kilometers_per_second': '10.6190040323',
#        'kilometers_per_hour': '38228.4145164107',
#        'miles_per_hour': '23753.6501199331'},
# ...
#     'close_approach_data': [{'close_approach_date': '2024-06-16',
#       'close_approach_date_full': '2024-Jun-16 00:13',
#       'epoch_date_close_approach': 1718496780000,
#       'relative_velocity': {'kilometers_per_second': '20.9258827982',
#        'kilometers_per_hour': '75333.1780734588',
#        'miles_per_hour': '46809.1072312556'},
#       'miss_distance': {'astronomical': '0.3162743335',
#        'lunar': '123.0307157315',
#        'kilometers': '47313966.627269645',
#        'miles': '29399535.587605301'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3842767?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '3842767',
#     'neo_reference_id': '3842767',
#     'name': '(2019 LR1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3842767',
#     'absolute_magnitude_h': 24.45,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0342416731,
#       'estimated_diameter_max': 0.0765667087},
#      'meters': {'estimated_diameter_min': 34.241673084,
#       'estimated_diameter_max': 76.5667086792},
#      'miles': {'estimated_diameter_min': 0.0212767826,
#       'estimated_diameter_max': 0.0475763323},
#      'feet': {'estimated_diameter_min': 112.3414507209,
#       'estimated_diameter_max': 251.2031205029}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-16',
#       'close_approach_date_full': '2024-Jun-16 10:48',
#       'epoch_date_close_approach': 1718534880000,
#       'relative_velocity': {'kilometers_per_second': '9.5899587692',
#        'kilometers_per_hour': '34523.8515690338',
#        'miles_per_hour': '21451.7787707699'},
#       'miss_distance': {'astronomical': '0.0960615327',
#        'lunar': '37.3679362203',
#        'kilometers': '14370600.680855349',
#        'miles': '8929477.1977238562'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54209483?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54209483',
#     'neo_reference_id': '54209483',
#     'name': '(2021 TH15)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54209483',
#     'absolute_magnitude_h': 28.88,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0044519982,
#       'estimated_diameter_max': 0.0099549705},
#      'meters': {'estimated_diameter_min': 4.4519981645,
#       'estimated_diameter_max': 9.9549705315},
#      'miles': {'estimated_diameter_min': 0.0027663426,
#       'estimated_diameter_max': 0.00618573},
#      'feet': {'estimated_diameter_min': 14.6062936579,
#       'estimated_diameter_max': 32.6606655185}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-16',
#       'close_approach_date_full': '2024-Jun-16 05:27',
#       'epoch_date_close_approach': 1718515620000,
#       'relative_velocity': {'kilometers_per_second': '17.8470329378',
#        'kilometers_per_hour': '64249.3185760235',
#        'miles_per_hour': '39922.0279785297'},
#       'miss_distance': {'astronomical': '0.2121755806',
#        'lunar': '82.5363008534',
#        'kilometers': '31741014.923773322',
#        'miles': '19722952.1081909636'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': True,
#     'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54209483?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54330730?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54330730',
#     'neo_reference_id': '54330730',
#     'name': '(2022 WK10)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54330730',
#     'absolute_magnitude_h': 20.85,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1797028549,
#       'estimated_diameter_max': 0.4018277992},
#      'meters': {'estimated_diameter_min': 179.7028548592,
#       'estimated_diameter_max': 401.8277992159},
#      'miles': {'estimated_diameter_min': 0.1116621426,
#       'estimated_diameter_max': 0.2496841414},
#      'feet': {'estimated_diameter_min': 589.5763143362,
#       'estimated_diameter_max': 1318.3327167796}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-16',
#       'close_approach_date_full': '2024-Jun-16 17:52',
#       'epoch_date_close_approach': 1718560320000,
#       'relative_velocity': {'kilometers_per_second': '20.6185358224',
#        'kilometers_per_hour': '74226.7289606519',
#        'miles_per_hour': '46121.6027811339'},
#       'miss_distance': {'astronomical': '0.2071806625',
#        'lunar': '80.5932777125',
#        'kilometers': '30993785.815188875',
#        'miles': '19258645.470301475'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54358249?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54358249',
#     'neo_reference_id': '54358249',
#     'name': '(2023 JX1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54358249',
#     'absolute_magnitude_h': 24.71,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0303777061,
#       'estimated_diameter_max': 0.0679266159},
#      'meters': {'estimated_diameter_min': 30.3777061387,
#       'estimated_diameter_max': 67.9266159267},
#      'miles': {'estimated_diameter_min': 0.0188758256,
#       'estimated_diameter_max': 0.0422076293},
#      'feet': {'estimated_diameter_min': 99.6643934081,
#       'estimated_diameter_max': 222.8563585969}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-16',
#       'close_approach_date_full': '2024-Jun-16 16:06',
#       'epoch_date_close_approach': 1718553960000,
#       'relative_velocity': {'kilometers_per_second': '9.5012822741',
#        'kilometers_per_hour': '34204.6161866182',
#        'miles_per_hour': '21253.4183188462'},
#       'miss_distance': {'astronomical': '0.292001794',
#        'lunar': '113.588697866',
#        'kilometers': '43682846.41857878',
#        'miles': '27143262.114715964'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54444915?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54444915',
#     'neo_reference_id': '54444915',
#     'name': '(2024 KK)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54444915',
#     'absolute_magnitude_h': 24.62,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0316632126,
#       'estimated_diameter_max': 0.0708010957},
#      'meters': {'estimated_diameter_min': 31.6632125734,
#       'estimated_diameter_max': 70.8010957001},
#      'miles': {'estimated_diameter_min': 0.0196746021,
#       'estimated_diameter_max': 0.0439937476},
#      'feet': {'estimated_diameter_min': 103.8819343392,
#       'estimated_diameter_max': 232.2870668166}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-16',
#       'close_approach_date_full': '2024-Jun-16 03:07',
#       'epoch_date_close_approach': 1718507220000,
#       'relative_velocity': {'kilometers_per_second': '7.8255764054',
#        'kilometers_per_hour': '28172.0750593728',
#        'miles_per_hour': '17505.0318611975'},
#       'miss_distance': {'astronomical': '0.0534238654',
#        'lunar': '20.7818836406',
#        'kilometers': '7992096.471006698',
#        'miles': '4966058.4678925124'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54445844?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54445844',
#     'neo_reference_id': '54445844',
#     'name': '(2024 LC1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54445844',
#     'absolute_magnitude_h': 20.274,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2342906604,
#       'estimated_diameter_max': 0.5238898432},
#      'meters': {'estimated_diameter_min': 234.2906604421,
#       'estimated_diameter_max': 523.8898432418},
#      'miles': {'estimated_diameter_min': 0.145581422,
#       'estimated_diameter_max': 0.3255299558},
#      'feet': {'estimated_diameter_min': 768.6701704048,
#       'estimated_diameter_max': 1718.7987533014}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-06-16',
#       'close_approach_date_full': '2024-Jun-16 20:04',
#       'epoch_date_close_approach': 1718568240000,
#       'relative_velocity': {'kilometers_per_second': '23.1519665562',
#        'kilometers_per_hour': '83347.079602253',
#        'miles_per_hour': '51788.6339895222'},
#       'miss_distance': {'astronomical': '0.234229201',
#        'lunar': '91.115159189',
#        'kilometers': '35040189.56140187',
#        'miles': '21772964.167691006'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54445924?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54445924',
#     'neo_reference_id': '54445924',
#     'name': '(2024 LS1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54445924',
#     'absolute_magnitude_h': 21.42,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1382149359,
#       'estimated_diameter_max': 0.3090579921},
#      'meters': {'estimated_diameter_min': 138.2149358786,
#       'estimated_diameter_max': 309.0579921303},
#      'miles': {'estimated_diameter_min': 0.0858827529,
#       'estimated_diameter_max': 0.1920396736},
#      'feet': {'estimated_diameter_min': 453.461090228,
#       'estimated_diameter_max': 1013.9698229009}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-16',
#       'close_approach_date_full': '2024-Jun-16 20:27',
#       'epoch_date_close_approach': 1718569620000,
#       'relative_velocity': {'kilometers_per_second': '4.8137252069',
#        'kilometers_per_hour': '17329.4107446624',
#        'miles_per_hour': '10767.8219152043'},
#       'miss_distance': {'astronomical': '0.3356359145',
#        'lunar': '130.5623707405',
#        'kilometers': '50210417.904702115',
#        'miles': '31199306.954894587'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54446666?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54446666',
#     'neo_reference_id': '54446666',
#     'name': '(2024 LH3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54446666',
#     'absolute_magnitude_h': 24.33,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0361871997,
#       'estimated_diameter_max': 0.0809170384},
#      'meters': {'estimated_diameter_min': 36.1871996599,
#       'estimated_diameter_max': 80.917038355},
#      'miles': {'estimated_diameter_min': 0.0224856764,
#       'estimated_diameter_max': 0.050279501},
#      'feet': {'estimated_diameter_min': 118.7244121323,
#       'estimated_diameter_max': 265.4758561166}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-16',
#       'close_approach_date_full': '2024-Jun-16 21:51',
#       'epoch_date_close_approach': 1718574660000,
#       'relative_velocity': {'kilometers_per_second': '6.1251534016',
#        'kilometers_per_hour': '22050.5522458724',
#        'miles_per_hour': '13701.3556441089'},
#       'miss_distance': {'astronomical': '0.0332735234',
#        'lunar': '12.9434006026',
#        'kilometers': '4977648.228035158',
#        'miles': '3092967.1861068604'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54446789?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54446789',
#     'neo_reference_id': '54446789',
#     'name': '(2024 LB4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54446789',
#     'absolute_magnitude_h': 25.431,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0217949048,
#       'estimated_diameter_max': 0.0487348887},
#      'meters': {'estimated_diameter_min': 21.7949048123,
#       'estimated_diameter_max': 48.7348887233},
#      'miles': {'estimated_diameter_min': 0.0135427218,
#       'estimated_diameter_max': 0.0302824465},
#      'feet': {'estimated_diameter_min': 71.5055955043,
#       'estimated_diameter_max': 159.8913723191}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-16',
#       'close_approach_date_full': '2024-Jun-16 11:23',
#       'epoch_date_close_approach': 1718536980000,
#       'relative_velocity': {'kilometers_per_second': '7.5944854325',
#        'kilometers_per_hour': '27340.1475571736',
#        'miles_per_hour': '16988.1044640671'},
#       'miss_distance': {'astronomical': '0.019400812',
#        'lunar': '7.546915868',
#        'kilometers': '2902320.15147044',
#        'miles': '1803418.116514472'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54447403?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54447403',
#     'neo_reference_id': '54447403',
#     'name': '(2024 LP4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54447403',
#     'absolute_magnitude_h': 23.457,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0540947324,
#       'estimated_diameter_max': 0.1209594988},
#      'meters': {'estimated_diameter_min': 54.0947323842,
#       'estimated_diameter_max': 120.9594988358},
#      'miles': {'estimated_diameter_min': 0.033612898,
#       'estimated_diameter_max': 0.0751607248},
#      'feet': {'estimated_diameter_min': 177.4761617955,
#       'estimated_diameter_max': 396.8487621605}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-16',
#       'close_approach_date_full': '2024-Jun-16 21:11',
#       'epoch_date_close_approach': 1718572260000,
#       'relative_velocity': {'kilometers_per_second': '11.1789469087',
#        'kilometers_per_hour': '40244.2088714417',
#        'miles_per_hour': '25006.1863401466'},
#       'miss_distance': {'astronomical': '0.0547385521',
#        'lunar': '21.2932967669',
#        'kilometers': '8188770.801044027',
#        'miles': '5088266.2297284926'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54447407?api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'},
#     'id': '54447407',
#     'neo_reference_id': '54447407',
#     'name': '(2024 LZ4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54447407',
#     'absolute_magnitude_h': 25.952,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0171456904,
#       'estimated_diameter_max': 0.0383389292},
#      'meters': {'estimated_diameter_min': 17.1456903687,
#       'estimated_diameter_max': 38.3389291856},
#      'miles': {'estimated_diameter_min': 0.0106538348,
#       'estimated_diameter_max': 0.0238226988},
#      'feet': {'estimated_diameter_min': 56.2522667893,
#       'estimated_diameter_max': 125.7838924293}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-06-16',
#       'close_approach_date_full': '2024-Jun-16 03:55',
#       'epoch_date_close_approach': 1718510100000,
#       'relative_velocity': {'kilometers_per_second': '21.4190383675',
#        'kilometers_per_hour': '77108.538122978',
#        'miles_per_hour': '47912.2469242471'},
#       'miss_distance': {'astronomical': '0.0018637539',
#        'lunar': '0.7250002671',
#        'kilometers': '278813.613644193',
#        'miles': '173246.7459601434'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}]}}

# %% [markdown]
# Para entender mejor este json, vamos a revisar las keys primero:

# %%
data.keys()
# Out:
# dict_keys(['links', 'element_count', 'near_earth_objects'])

# %%
data['links']
# Out:
# {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-06-23&end_date=2024-06-30&detailed=false&api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d',
#  'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-06-09&end_date=2024-06-16&detailed=false&api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d',
#  'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-06-16&end_date=2024-06-23&detailed=false&api_key=2XGCNsKXdktTyQ3CV9rpVD233gV1xPhghaktuu0d'}

# %% [markdown]
# Esta metadata nos dice qué link es el que solicitamos (self) y el siguiente link que tendríamos que usar para pedir los datos posteriores (next). Esto está buenísimo porque nos permite automatizar nuestras llamadas. Al siempre saber cuál es el link que sigue, podemos extraerlo de ahí y realizar una nueva llamada.

# %%
data['element_count']
# Out:
# 102

# %%
data['near_earth_objects'].keys()
# Out:
# dict_keys(['2024-06-19', '2024-06-18', '2024-06-17', '2024-06-23', '2024-06-22', '2024-06-21', '2024-06-20', '2024-06-16'])

# %% [markdown]
# ¡Estos son nuestros datos! Podemos ver que tenemos una lista con diccionarios dentro. Esto es algo que podemos leer directamente en pandas. Vamos a hacer eso. Debido a que el json que tenemos tiene muchos datos "anidados" (diccionarios dentro de diccionarios dentro de diccionarios), necesitamos primero "normalizar" nuestros datos. Esto básicamente significa extraer los datos anidados para convertirlos en su propia columna (puedes aprender más sobre este proceso aquí). Simplemente hay que usar el siguiente código:

# %%
import pandas as pd

# %%
normalized = pd.json_normalize(data['near_earth_objects']['2024-09-10'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 normalized = pd.json_normalize(data['near_earth_objects']['2024-09-10'])
#
# KeyError: '2024-09-10'

# %%
type(normalized)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.DataFrame(normalized)

# %%
df.head()
# Out:
#         id neo_reference_id         name  \
# 0  3304382          3304382   (2005 WR2)
# 1  3426807          3426807  (2008 RQ24)
# 2  3616348          3616348   (2012 VH5)
# 3  3648844          3648844   (2013 TR4)
# 4  3826885          3826885    (2018 QR)
#
#                                         nasa_jpl_url  absolute_magnitude_h  \
# 0  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 19.52
# 1  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 20.80
# 2  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 22.49
# 3  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 23.24
# 4  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 24.70
#
#    is_potentially_hazardous_asteroid  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
#                                  close_approach_data  is_sentry_object  \
# 0  [{'close_approach_date': '2024-09-10', 'close_...             False
# 1  [{'close_approach_date': '2024-09-10', 'close_...             False
# 2  [{'close_approach_date': '2024-09-10', 'close_...             False
# 3  [{'close_approach_date': '2024-09-10', 'close_...             False
# 4  [{'close_approach_date': '2024-09-10', 'close_...             False
#
#                                           links.self  \
# 0  http://api.nasa.gov/neo/rest/v1/neo/3304382?ap...
# 1  http://api.nasa.gov/neo/rest/v1/neo/3426807?ap...
# 2  http://api.nasa.gov/neo/rest/v1/neo/3616348?ap...
# 3  http://api.nasa.gov/neo/rest/v1/neo/3648844?ap...
# 4  http://api.nasa.gov/neo/rest/v1/neo/3826885?ap...
#
#    estimated_diameter.kilometers.estimated_diameter_min  \
# 0                                           0.331555
# 1                                           0.183889
# 2                                           0.084441
# 3                                           0.059780
# 4                                           0.030518
#
#    estimated_diameter.kilometers.estimated_diameter_max  \
# 0                                           0.741378
# 1                                           0.411188
# 2                                           0.188817
# 3                                           0.133672
# 4                                           0.068240
#
#    estimated_diameter.meters.estimated_diameter_min  \
# 0                                        331.554538
# 1                                        183.888672
# 2                                         84.441313
# 3                                         59.779871
# 4                                         30.517923
#
#    estimated_diameter.meters.estimated_diameter_max  \
# 0                                        741.378485
# 1                                        411.187571
# 2                                        188.816516
# 3                                        133.671856
# 4                                         68.240151
#
#    estimated_diameter.miles.estimated_diameter_min  \
# 0                                         0.206018
# 1                                         0.114263
# 2                                         0.052469
# 3                                         0.037145
# 4                                         0.018963
#
#    estimated_diameter.miles.estimated_diameter_max  \
# 0                                         0.460671
# 1                                         0.255500
# 2                                         0.117325
# 3                                         0.083060
# 4                                         0.042402
#
#    estimated_diameter.feet.estimated_diameter_min  \
# 0                                     1087.777391
# 1                                      603.309311
# 2                                      277.038437
# 3                                      196.128193
# 4                                      100.124423
#
#    estimated_diameter.feet.estimated_diameter_max
# 0                                     2432.344190
# 1                                     1349.040631
# 2                                      619.476777
# 3                                      438.555973
# 4                                      223.885017

# %%
df.columns
# Out:
# Index(['id', 'neo_reference_id', 'name', 'nasa_jpl_url',
#        'absolute_magnitude_h', 'is_potentially_hazardous_asteroid',
#        'close_approach_data', 'is_sentry_object', 'links.self',
#        'estimated_diameter.kilometers.estimated_diameter_min',
#        'estimated_diameter.kilometers.estimated_diameter_max',
#        'estimated_diameter.meters.estimated_diameter_min',
#        'estimated_diameter.meters.estimated_diameter_max',
#        'estimated_diameter.miles.estimated_diameter_min',
#        'estimated_diameter.miles.estimated_diameter_max',
#        'estimated_diameter.feet.estimated_diameter_min',
#        'estimated_diameter.feet.estimated_diameter_max'],
#       dtype='object')

# %%
df['close_approach_data']
# Out:
# 0     [{'close_approach_date': '2024-09-10', 'close_...
# 1     [{'close_approach_date': '2024-09-10', 'close_...
# 2     [{'close_approach_date': '2024-09-10', 'close_...
# 3     [{'close_approach_date': '2024-09-10', 'close_...
# 4     [{'close_approach_date': '2024-09-10', 'close_...
# 5     [{'close_approach_date': '2024-09-10', 'close_...
# 6     [{'close_approach_date': '2024-09-10', 'close_...
# 7     [{'close_approach_date': '2024-09-10', 'close_...
# 8     [{'close_approach_date': '2024-09-10', 'close_...
# 9     [{'close_approach_date': '2024-09-10', 'close_...
# 10    [{'close_approach_date': '2024-09-10', 'close_...
# 11    [{'close_approach_date': '2024-09-10', 'close_...
# 12    [{'close_approach_date': '2024-09-10', 'close_...
# Name: close_approach_data, dtype: object

# %%
df_lista_flat = df.explode('close_approach_data')

# %%
df_lista_flat
# Out:
#           id neo_reference_id               name  \
# 0    3304382          3304382         (2005 WR2)
# 1    3426807          3426807        (2008 RQ24)
# 2    3616348          3616348         (2012 VH5)
# 3    3648844          3648844         (2013 TR4)
# 4    3826885          3826885          (2018 QR)
# 5   54016590         54016590         (2020 HP1)
# 6   54053850         54053850         (2020 PM7)
# 7   54194978         54194978         (2021 RU7)
# 8   54239834         54239834         (2022 BA1)
# 9   54293318         54293318         (2020 CO8)
# 10  54358767         54358767         (2023 JA4)
# 11   2662203          2662203  662203 (2005 WR2)
# 12  54440648         54440648         (2024 JB6)
#
#                                          nasa_jpl_url  absolute_magnitude_h  \
# 0   https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 19.52
# 1   https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 20.80
# 2   https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 22.49
# 3   https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 23.24
# 4   https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 24.70
# 5   https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 28.60
# 6   https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 22.31
# 7   https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 23.47
# 8   https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 22.58
# 9   https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 28.00
# 10  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 23.20
# 11  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 19.48
# 12  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 19.95
#
#     is_potentially_hazardous_asteroid  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
# 5                               False
# 6                               False
# 7                               False
# 8                               False
# 9                               False
# 10                              False
# 11                              False
# 12                               True
#
#                                   close_approach_data  is_sentry_object  \
# 0   {'close_approach_date': '2024-09-10', 'close_a...             False
# 1   {'close_approach_date': '2024-09-10', 'close_a...             False
# 2   {'close_approach_date': '2024-09-10', 'close_a...             False
# 3   {'close_approach_date': '2024-09-10', 'close_a...             False
# 4   {'close_approach_date': '2024-09-10', 'close_a...             False
# 5   {'close_approach_date': '2024-09-10', 'close_a...             False
# 6   {'close_approach_date': '2024-09-10', 'close_a...             False
# 7   {'close_approach_date': '2024-09-10', 'close_a...             False
# 8   {'close_approach_date': '2024-09-10', 'close_a...             False
# 9   {'close_approach_date': '2024-09-10', 'close_a...             False
# 10  {'close_approach_date': '2024-09-10', 'close_a...             False
# 11  {'close_approach_date': '2024-09-10', 'close_a...             False
# 12  {'close_approach_date': '2024-09-10', 'close_a...             False
#
#                                            links.self  \
# 0   http://api.nasa.gov/neo/rest/v1/neo/3304382?ap...
# 1   http://api.nasa.gov/neo/rest/v1/neo/3426807?ap...
# 2   http://api.nasa.gov/neo/rest/v1/neo/3616348?ap...
# 3   http://api.nasa.gov/neo/rest/v1/neo/3648844?ap...
# 4   http://api.nasa.gov/neo/rest/v1/neo/3826885?ap...
# 5   http://api.nasa.gov/neo/rest/v1/neo/54016590?a...
# 6   http://api.nasa.gov/neo/rest/v1/neo/54053850?a...
# 7   http://api.nasa.gov/neo/rest/v1/neo/54194978?a...
# 8   http://api.nasa.gov/neo/rest/v1/neo/54239834?a...
# 9   http://api.nasa.gov/neo/rest/v1/neo/54293318?a...
# 10  http://api.nasa.gov/neo/rest/v1/neo/54358767?a...
# 11  http://api.nasa.gov/neo/rest/v1/neo/2662203?ap...
# 12  http://api.nasa.gov/neo/rest/v1/neo/54440648?a...
#
#     estimated_diameter.kilometers.estimated_diameter_min  \
# 0                                            0.331555
# 1                                            0.183889
# 2                                            0.084441
# 3                                            0.059780
# 4                                            0.030518
# 5                                            0.005065
# 6                                            0.091739
# 7                                            0.053772
# 8                                            0.081013
# 9                                            0.006677
# 10                                           0.060891
# 11                                           0.337719
# 12                                           0.271991
#
#     estimated_diameter.kilometers.estimated_diameter_max  \
# 0                                            0.741378
# 1                                            0.411188
# 2                                            0.188817
# 3                                            0.133672
# 4                                            0.068240
# 5                                            0.011325
# 6                                            0.205135
# 7                                            0.120238
# 8                                            0.181151
# 9                                            0.014929
# 10                                           0.136157
# 11                                           0.755162
# 12                                           0.608191
#
#     estimated_diameter.meters.estimated_diameter_min  \
# 0                                         331.554538
# 1                                         183.888672
# 2                                          84.441313
# 3                                          59.779871
# 4                                          30.517923
# 5                                           5.064715
# 6                                          91.739206
# 7                                          53.771850
# 8                                          81.013049
# 9                                           6.676594
# 10                                         60.891262
# 11                                        337.718597
# 12                                        271.991277
#
#     estimated_diameter.meters.estimated_diameter_max  \
# 0                                         741.378485
# 1                                         411.187571
# 2                                         188.816516
# 3                                         133.671856
# 4                                          68.240151
# 5                                          11.325046
# 6                                         205.135101
# 7                                         120.237511
# 8                                         181.150684
# 9                                          14.929318
# 10                                        136.157002
# 11                                        755.161741
# 12                                        608.190985
#
#     estimated_diameter.miles.estimated_diameter_min  \
# 0                                          0.206018
# 1                                          0.114263
# 2                                          0.052469
# 3                                          0.037145
# 4                                          0.018963
# 5                                          0.003147
# 6                                          0.057004
# 7                                          0.033412
# 8                                          0.050339
# 9                                          0.004149
# 10                                         0.037836
# 11                                         0.209849
# 12                                         0.169007
#
#     estimated_diameter.miles.estimated_diameter_max  \
# 0                                          0.460671
# 1                                          0.255500
# 2                                          0.117325
# 3                                          0.083060
# 4                                          0.042402
# 5                                          0.007037
# 6                                          0.127465
# 7                                          0.074712
# 8                                          0.112562
# 9                                          0.009277
# 10                                         0.084604
# 11                                         0.469236
# 12                                         0.377912
#
#     estimated_diameter.feet.estimated_diameter_min  \
# 0                                      1087.777391
# 1                                       603.309311
# 2                                       277.038437
# 3                                       196.128193
# 4                                       100.124423
# 5                                        16.616518
# 6                                       300.981656
# 7                                       176.416836
# 8                                       265.790851
# 9                                        21.904837
# 10                                      199.774489
# 11                                     1108.000682
# 12                                      892.359862
#
#     estimated_diameter.feet.estimated_diameter_max
# 0                                      2432.344190
# 1                                      1349.040631
# 2                                       619.476777
# 3                                       438.555973
# 4                                       223.885017
# 5                                        37.155664
# 6                                       673.015444
# 7                                       394.480037
# 8                                       594.326411
# 9                                        48.980705
# 10                                      446.709337
# 11                                     2477.564845
# 12                                     1995.377313

# %%
df_lista_flat = pd.json_normalize(df_lista_flat['close_approach_data'])

# %%
df_lista_flat
# Out:
#    close_approach_date close_approach_date_full  epoch_date_close_approach  \
# 0           2024-09-10        2024-Sep-10 11:45              1725968700000
# 1           2024-09-10        2024-Sep-10 03:23              1725938580000
# 2           2024-09-10        2024-Sep-10 16:30              1725985800000
# 3           2024-09-10        2024-Sep-10 00:30              1725928200000
# 4           2024-09-10        2024-Sep-10 18:37              1725993420000
# 5           2024-09-10        2024-Sep-10 00:26              1725927960000
# 6           2024-09-10        2024-Sep-10 00:16              1725927360000
# 7           2024-09-10        2024-Sep-10 20:52              1726001520000
# 8           2024-09-10        2024-Sep-10 13:13              1725973980000
# 9           2024-09-10        2024-Sep-10 19:39              1725997140000
# 10          2024-09-10        2024-Sep-10 00:47              1725929220000
# 11          2024-09-10        2024-Sep-10 11:45              1725968700000
# 12          2024-09-10        2024-Sep-10 05:17              1725945420000
#
#    orbiting_body relative_velocity.kilometers_per_second  \
# 0          Earth                           14.6351290871
# 1          Earth                            3.6435135721
# 2          Earth                            7.8735077501
# 3          Earth                            9.1901151332
# 4          Earth                              10.7313597
# 5          Earth                            9.7341157063
# 6          Earth                           10.3710086039
# 7          Earth                            11.658214134
# 8          Earth                           24.9481370409
# 9          Earth                            9.0363532405
# 10         Earth                           19.6751651559
# 11         Earth                           14.6351306674
# 12         Earth                           18.9821633446
#
#    relative_velocity.kilometers_per_hour relative_velocity.miles_per_hour  \
# 0                       52686.4647136903                  32737.320255015
# 1                        13116.648859541                  8150.1755094187
# 2                       28344.6279002435                 17612.2494861263
# 3                       33084.4144796243                 20557.3685415199
# 4                       38632.8949200436                 24004.9785129571
# 5                       35042.8165427157                 21774.2434234446
# 6                       37335.6309741995                  23198.909146163
# 7                       41969.5708822506                 26078.2591962518
# 8                        89813.293347231                 55806.4877467836
# 9                       32530.8716658842                 20213.4185637268
# 10                      70830.5945611698                 44011.3769371891
# 11                      52686.4704025748                 32737.3237898666
# 12                      68335.7880404365                  42461.201185459
#
#    miss_distance.astronomical miss_distance.lunar miss_distance.kilometers  \
# 0                0.3201471511      124.5372417779       47893331.891128157
# 1                0.2460051145       95.6959895405       36801841.138306115
# 2                0.3124953362      121.5606857818       46748636.680453894
# 3                0.2288848305       89.0361990645       34240683.118111035
# 4                0.2945986168      114.5988619352       44071325.578226216
# 5                0.2072319934       80.6132454326       31001464.808494058
# 6                0.0762722876       29.6699198764       11410171.764987412
# 7                0.2540391989       98.8212483721       38003723.051946343
# 8                0.3591632805      139.7145161145       53730061.745012535
# 9                0.1064886516       41.4240854724       15930475.458532092
# 10               0.4669829344      181.6563614816       69859652.312589728
# 11                0.320147172       124.537249908        47893335.01772364
# 12               0.3625416165      141.0286888185       54235453.614756855
#
#     miss_distance.miles
# 0   29759536.4691042866
# 1    22867603.698469787
# 2   29048255.8477119772
# 3    21276173.900300883
# 4   27384651.8711291408
# 5   19263416.9754836804
# 6    7089951.9693218056
# 7   23614418.4893438134
# 8    33386312.224481583
# 9    9898738.4393311896
# 10  43408775.0553971264
# 11   29759538.411880632
# 12   33700348.170300399

# %% [markdown]
# # Excepciones
#
# Hay veces que algún error (una Exception) sucede durante la ejecución de nuestro programa, Python lo detecta y detiene el programa completo para evitar que el error cause problemas. Por ejemplo, aquí tenemos un error que sucede durante la lectura de una llave inexistente en un diccionario:

# %%
diccionario = {
    0:['a','b','c'],
    1:['d','e','f'],
    2:['g','h','i']
}

# %%
diccionario[3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 diccionario[3]
#
# KeyError: 3

# %%
try:
    diccionario[3]
except:
    print("La llave no existe en el diccionario")
# Out:
# La llave no existe en el diccionario

# %% [markdown]
# # Concatenación de DataFrames
#
# pandas ofrece varias maneras de unir DataFrames un solo DataFrame. Una de ellas es la función pd.concat. pd.concat te permite concatenar Series y DataFrames usando diferentes axis. Comencemos con las Series.
#
# pd.concat con Series
# Tenemos las siguientes dos Series:

# %%
serie_1 = pd.Series([1,2,3], index=['a','b', 'c'])
serie_2 = pd.Series([4,5,6], index=['d','f', 'g'])

# %%
serie_1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
serie_2
# Out:
# d    4
# f    5
# g    6
# dtype: int64

# %% [markdown]
# Podemos unirlas de manera vertical llamando pd.concat con axis=0. Observa que tenemos que pasarle las dos Series dentro de una lista:

# %%
pd.concat([serie_1, serie_2], axis=0)
pd.concat([serie_1, serie_2], axis='index')
# Out:
# a    1
# b    2
# c    3
# d    4
# f    5
# g    6
# dtype: int64

# %% [markdown]
# Si queremos unirlas horizontalmente, podemos llamar la función usando axis=1:

# %%
pd.concat([serie_1, serie_2], axis=1)
pd.concat([serie_1, serie_2], axis="columns")
# Out:
#      0    1
# a  1.0  NaN
# b  2.0  NaN
# c  3.0  NaN
# d  NaN  4.0
# f  NaN  5.0
# g  NaN  6.0

# %% [markdown]
# Aquí hay dos cosas que observar:
#
# 1. Usé el argumento keys para ponerle nombre a las columnas (ya que las Series originales no tenían nombres).
# 2. Debido a que las Series tienen diferentes índices, la concatenación horizontal deja muchos valores vacíos. Esto se debe a que la serie_1 no tiene valores que correspondan a los índices 'd', 'f', y 'e'; mientras que la serie_2 no tiene valores que correspondan a los índices 'a', 'b', y 'c'.
#
# Mira lo que pasa si concatenamos dos Series que compartan el mismo índice:

# %%
serie_3 = pd.Series([7,8,9], index=['a','b','c'])
serie_3
# Out:
# a    7
# b    8
# c    9
# dtype: int64

# %%
serie_1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
pd.concat([serie_1,serie_3], axis=1, keys=['serie1', 'serie2'])
# Out:
#    serie1  serie2
# a       1       7
# b       2       8
# c       3       9

# %% [markdown]
# Si concatenamos verticalmente dos Series que comparten el mismo índice, tenemos un pequeño problema:

# %%
pd.concat([serie_1,serie_3], axis=0)
# Out:
# a    1
# b    2
# c    3
# a    7
# b    8
# c    9
# dtype: int64

# %% [markdown]
# Como ves, el índice se repite. Hay veces que esto es justo lo que queremos, pero en este caso, no parece muy deseable. En este caso tenemos dos opciones.
#
# 1. Si no nos interesa mucho el índice actual, podemos resetearlo para obtener uno nuevo donde no haya repeticiones:

# %%
pd.concat([serie_1,serie_3], axis=0).reset_index(drop=True)
# Out:
# 0    1
# 1    2
# 2    3
# 3    7
# 4    8
# 5    9
# dtype: int64

# %% [markdown]
# 2. En caso de que sí nos interese el índice, pero queramos poder diferenciar entre los índices que vienen de la serie_1 y los que vienen de la serie_3, podemos usar el argumento keys para agregar un segundo nivel en el índice:

# %%
pd.concat([serie_1,serie_3], axis=0, keys=['serie_1', 'serie_3'])
# Out:
# serie_1  a    1
#          b    2
#          c    3
# serie_3  a    7
#          b    8
#          c    9
# dtype: int64

# %% [markdown]
# ¡¿Khá?! ¿Y eso qué es? ¿Un segundo nivel de índice? Pues sí, aunque no lo creas, podemos crear diferentes niveles de índices que nos ayudan a segmentar nuestros datos a más detalle. Existen los Multiíndices de filas y también de columnas. En este caso, tenemos uno de filas.
#
# Pequeña digresión para hablar sobre Multíndices en Filas
#
# Que no cunda el pánico. Si quisieras acceder a tus datos usando loc simplemente tendrías que hacer algo como esto:

# %%
concat_1 =pd.concat([serie_1,serie_3], axis=0, keys=['serie_1', 'serie_3'])

# %%
concat_1.loc['serie_1', 'b']
# Out:
# 2

# %% [markdown]
# ¿Ves? como primer argumento a nuestro loc, en vez de un solo valor, le pasamos una tupla de valores. Una tupla es eso que ves dentro de dos paréntesis (('serie_1', 'b')). Es una manera de contener dos o más valores. En este caso, nuestros dos valores son los dos niveles de nuestro índice que queremos acceder: primero serie_1 y después b. Si queremos acceder al índice b de la serie_3, haríamos lo siguiente:

# %%
concat_1.loc['serie_3', 'b']
# Out:
# 8

# %% [markdown]
# Podríamos concatenar muchas Series con los mismos índices y mantenerlas segmentadas usando multiíndices:

# %%
serie_4 = pd.Series([10,11,12], index=['a','b','c'])
serie_5 = pd.Series([13,14,15], index=['a','b','c'])

concat_2 = pd.concat([serie_1,serie_3,serie_4, serie_5], axis=0,keys=['serie_1','serie_3', 'serie_4', 'serie_5'])

concat_2
# Out:
# serie_1  a     1
#          b     2
#          c     3
# serie_3  a     7
#          b     8
#          c     9
# serie_4  a    10
#          b    11
#          c    12
# serie_5  a    13
#          b    14
#          c    15
# dtype: int64

# %% [markdown]
# Lo más genial es que si accedemos a la nueva Serie usando sólo el primer nivel, obtenemos una de nuestras Series completa:

# %%
concat_2.loc['serie_4']
# Out:
# a    10
# b    11
# c    12
# dtype: int64

# %% [markdown]
# Pero bueno, salgamos de nuestra pequeña digresión para hablar sobre concatenación de DataFrames.
#
# pd.concat con DataFrames
# La misma lógica aplica para la unión de DataFrames. Tenemos ahora dos DataFrames:

# %%
data_1 ={
    'column_1':[1,2,3],
    'column_2':[4,5,6]
}

df_1 =pd.DataFrame(data_1,  index=['a','b','c'])
df_1
# Out:
#    column_1  column_2
# a         1         4
# b         2         5
# c         3         6

# %%
data_1 ={
    'column_1':[7,8,9],
    'column_2':[10,11,12]
}

df_2 =pd.DataFrame(data_1, index=['d','e','f'])
df_2
# Out:
#    column_1  column_2
# d         7        10
# e         8        11
# f         9        12

# %% [markdown]
# Usamos axis=0 para concatenarlos verticalmente:

# %%
pd.concat([df_1,df_2], axis='index')
# Out:
#    column_1  column_2
# a         1         4
# b         2         5
# c         3         6
# d         7        10
# e         8        11
# f         9        12

# %% [markdown]
# Si usamos axis=1 de nuevo vamos a tener valores NaN porque los DataFrames no comparten índice:

# %%
pd.concat([df_1,df_2], axis='columns')
# Out:
#    column_1  column_2  column_1  column_2
# a       1.0       4.0       NaN       NaN
# b       2.0       5.0       NaN       NaN
# c       3.0       6.0       NaN       NaN
# d       NaN       NaN       7.0      10.0
# e       NaN       NaN       8.0      11.0
# f       NaN       NaN       9.0      12.0

# %% [markdown]
# Si los DataFrames comparten índice y queremos concatenarlos verticalmente, también podemos usar un multiíndice en las filas para diferenciarlos:
